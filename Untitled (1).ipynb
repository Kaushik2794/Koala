# %%
import requests
from bs4 import BeautifulSoup
makeup = requests.get('https://www.sephora.com/shop/makeup-cosmetics')
soup = BeautifulSoup(makeup.content, 'html.parser')
#print(soup.prettify())

soup.find_all('a')

links
# Out:
# <!DOCTYPE html>
# <html class="css-1esi5of" data-comp="Index" lang="en">
#  <head data-comp="Head">
#   <title>
#    Makeup | Sephora
#   </title>
#   <script>
# ...

# %%
links=[]

for link in soup.find_all('a',{'class': 'css-or7ouu'}):
    links.append(link['href'].replace('/shop',''))

# %%
<a data-at="top_level_category" class="css-or7ouu " href="/shop/face-makeup" data-comp="Link Box">Face<svg aria-hidden="true" viewBox="0 0 57 95" class="css-jzzu6q " data-comp="Chevron Box"><path d="M57 47.5L9.5 0 0 9.5l38 38-38 38L9.5 95 57 47.5z"></path></svg></a>

# %%
for link in links:
    print('https://www.sephora.com/shop'+link)
# Out:
# https://www.sephora.com/shop/new-makeup
# https://www.sephora.com/shop/makeup-kits-makeup-sets
# https://www.sephora.com/shop/mini-makeup
# https://www.sephora.com/shop/makeup-palettes
# https://www.sephora.com/shop/clean-makeup
# https://www.sephora.com/shop/face-makeup
# https://www.sephora.com/shop/eye-makeup
# https://www.sephora.com/shop/lips-makeup
# https://www.sephora.com/shop/cheek-makeup
# https://www.sephora.com/shop/makeup-applicators
# https://www.sephora.com/shop/makeup-accessories
# https://www.sephora.com/shop/nails-makeup

# %%
https://www.sephora.com/shop/face-makeup
# Out:
# ['/new-makeup',
#  '/makeup-kits-makeup-sets',
#  '/mini-makeup',
#  '/makeup-palettes',
#  '/clean-makeup',
#  '/face-makeup',
#  '/eye-makeup',
#  '/lips-makeup',
#  '/cheek-makeup',
#  '/makeup-applicators',
#  '/makeup-accessories',
#  '/nails-makeup']

# %%
face = requests.get('https://www.sephora.com/shop/face-makeup')
soup = BeautifulSoup(makeup.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="css-1esi5of" data-comp="Index" lang="en">
#  <head data-comp="Head">
#   <title>
#    Makeup | Sephora
#   </title>
#   <script>
# ...
